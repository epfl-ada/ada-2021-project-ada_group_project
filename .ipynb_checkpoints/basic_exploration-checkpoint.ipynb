# %% [markdown]
# ### Very Basic Extraction of Possibly Relevant Quotes

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
politicians = pd.read_csv("data/politicians.csv")

# %%
names = politicians.speaker

# %%
words = ['lesbian', 'gay', 'homosexual', 'gender', 'bisexual', 'sexuality', 'same sex'] # obviously add more

# %%
politicians
# Out:
#               state                speaker
# 0           Alabama         Richard Shelby
# 1           Alabama       Tommy Tuberville
# 2            Alaska         Lisa Murkowski
# 3            Alaska           Dan Sullivan
# 4           Arizona         Kyrsten Sinema
# ..              ...                    ...
# 690           Texas             Van Taylor
# 691           Texas       Veronica Escobar
# 692         Florida      W. Gregory Steube
# 693  South Carolina  William R. Timmons IV
# 694      New Mexico   Xochitl Torres Small
#
# [695 rows x 2 columns]

# %% [markdown]
# One way to upload the data:
# however it needs real large files, so we worked with an already made dataframe (created on the most robust computer of our group)

# %%
# only take rows with speakers in the congress or senator files
# only take rows with quotations that contain relevant words
chunk_num = 1
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        
        return chunk.loc[chunk.speaker.isin(names) & (chunk.quotation.str.contains('{}'.format("|".join(words))))]
            
        

with pd.read_json('data/quotes-2015.json.bz2', lines=True, compression='bz2', chunksize=100000) as df_reader:
    for chunk in df_reader:
        processed_chunk = process_chunk(chunk)
        if (chunk_num == 1):
            dataframe15 = processed_chunk
            chunk_num += 1
        else:
            dataframe15 = pd.concat([dataframe15, processed_chunk])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-71d7296b8cf3> in <module>
#       9
#      10
# ---> 11 with pd.read_json('data/quotes-2015.json.bz2', lines=True, compression='bz2', chunksize=100000) as df_reader:
#      12     for chunk in df_reader:
#      13         processed_chunk = process_chunk(chunk)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     595     )
#     596
# --> 597     json_reader = JsonReader(
#     598         filepath_or_buffer,
#     599         orient=orient,
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     677                 raise ValueError("nrows can only be passed if lines=True")
#     678
# --> 679         data = self._get_data_from_filepath(filepath_or_buffer)
#     680         self.data = self._preprocess_data(data)
#     681
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     716
#     717         if exists or self.compression is not None:
# --> 718             data, _ = get_handle(
#     719                 filepath_or_buffer,
#     720                 "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     452         elif compression == "bz2":
#     453             if is_path:
# --> 454                 f = bz2.BZ2File(
#     455                     path_or_buf, mode, **compression_args  # type: ignore
#     456                 )
#
# ~\anaconda3\lib\bz2.py in __init__(self, filename, mode, buffering, compresslevel)
#      94
#      95         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 96             self._fp = _builtin_open(filename, mode)
#      97             self._closefp = True
#      98             self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/quotes-2015.json.bz2'

# %% [markdown]
# The already made dataframe:

# %%
# Merge quote data with speaker state data
dataframe15=pd.read_csv("data/df15.csv")
merged = pd.merge(dataframe15, politicians, on='speaker', how='inner').drop(columns=['state_y', 'Unnamed: 0'])
merged.sample(5)
# Out:
#                quoteID                                          quotation  \
# 335  2015-09-14-062908  Let me be very frank. I understand that issues...
# 819  2015-06-20-051420  Whether it is a $20 dollar bill or a $10 dolla...
# 520  2015-12-17-042837  I think one of the biggest things the next pre...
# 779  2015-01-28-017758  For America to remain a leader in the innovati...
# 345  2015-09-29-140551  You have insulted thousands of gay people who ...
#
#                     speaker         qids                 date  numOccurrences  \
# 335          Bernie Sanders  ['Q359442']  2015-09-14 15:26:10               3
# 819            Joyce Beatty  ['Q976417']  2015-06-20 23:15:28               3
# 520             Marco Rubio  ['Q324546']  2015-12-17 20:19:50               1
# 779  Cathy McMorris Rodgers  ['Q293343']  2015-01-28 23:05:43               1
# 345          Bernie Sanders  ['Q359442']  2015-09-29 21:25:12               1
#
#                                                 probas  \
# 335  [['Bernie Sanders', '0.6038'], ['None', '0.374...
# 819  [['Joyce Beatty', '0.4267'], ['None', '0.3661'...
# 520    [['Marco Rubio', '0.8241'], ['None', '0.1759']]
# 779  [['Cathy McMorris Rodgers', '0.8079'], ['None'...
# 345  [['Bernie Sanders', '0.6292'], ['None', '0.309...
#
#                                                   urls phase     state_x
# 335  ['http://m.washingtonexaminer.com/sanders-seek...     E     Vermont
# 819  ['http://rssfeeds.usatoday.com/~/96661532/0/us...     E        Ohio
# 520  ['http://www.pridesource.com/article.html?arti...     E     Florida
# 779  ['http://www.hawaii247.com/2015/01/28/updates-...     E  Washington
# 345  ['http://politifact.com/punditfact/statements/...     E     Vermont

# %%
print("size of the data:",merged.shape)
# Out:
# size of the data: (844, 10)

# %% [markdown]
# To get an insight into the kind of quotations we are working with:

# %%
merged.quotation.sample(10)
# Out:
# 205    If we are going to continue to make progress, ...
# 383    not to abandon any segment of American society...
# 646    But I was incredibly lucky. My family went thr...
# 511    It doesn't exist. There is no federal constitu...
# 838    The issue of marriage equality is one that div...
# 139    On the Democratic side, the major donors that ...
# 415    In 1996, I faced another fork in the road-anot...
# 772    This legislation puts Ireland in the small van...
# 97     gotten so extreme and so radical in its devoti...
# 325    Sanders shared his thoughts on male and female...
# Name: quotation, dtype: object

# %% [markdown]
# Visualisation by states

# %%
merged.state_x.value_counts()
# Out:
# Texas                   198
# Vermont                 158
# Florida                  91
# California               62
# Kentucky                 51
# Illinois                 31
# South Carolina           24
# New York                 17
# Colorado                 14
# Wisconsin                13
# Iowa                     12
# Washington               12
# New Jersey               11
# Georgia                  11
# Ohio                     11
# Arizona                  11
# Hawaii                   10
# Kansas                    9
# Arkansas                  8
# Utah                      8
# Maine                     8
# Virginia                  7
# Oregon                    6
# Louisiana                 6
# Oklahoma                  5
# Alaska                    5
# Tennessee                 5
# Massachusetts             5
# Nevada                    4
# Maryland                  4
# Connecticut               3
# Pennsylvania              3
# Minnesota                 3
# Michigan                  3
# Nebraska                  3
# New Hampshire             2
# Rhode Island              2
# District of Columbia      2
# Delaware                  2
# North Dakota              1
# Wyoming                   1
# Alabama                   1
# New Mexico                1
# Name: state_x, dtype: int64

# %% [markdown]
# **Let's see what is the distribution of speakers per state on the matter of gay rights**

# %%
plt.figure(figsize=(13,5))
plt.hist(merged.state_x, bins= 50)
plt.xlabel('States')
plt.ylabel('Number of speakers')
plt.title('Distribution of speaker in each state')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### We can do the same for each year...

# %%
dataframe20=pd.read_csv("data/df20.csv")
merged = pd.merge(dataframe20, politicians, on='speaker', how='inner')
merged20=merged.drop(columns=['state_y', 'Unnamed: 0'])
merged20.sample(5)
# Out:
#                quoteID                                          quotation  \
# 56   2020-01-20-045528  Not at their gender, not at their sexuality, n...
# 168  2020-01-19-008349  Everybody brings some negatives, if you like. ...
# 139  2020-01-27-005290  And they're starting to think, `Could this rea...
# 184  2020-03-05-047035  My approach since has been rooted in an apprec...
# 210  2020-02-21-025682  I think also that there's still a lot that peo...
#
#               speaker                       qids                 date  \
# 56   Elizabeth Warren                ['Q434706']  2020-01-20 00:35:47
# 168    Bernie Sanders                ['Q359442']  2020-01-19 21:49:50
# 139    Bernie Sanders                ['Q359442']  2020-01-27 05:00:00
# 184      Aaron Schock   ['Q24705735', 'Q302659']  2020-03-05 00:00:00
# 210        Katie Hill  ['Q58416634', 'Q6377460']  2020-02-21 18:16:51
#
#      numOccurrences                                             probas  \
# 56                3  [['Elizabeth Warren', '0.5741'], ['None', '0.4...
# 168               3  [['Bernie Sanders', '0.7921'], ['None', '0.125...
# 139               2  [['Bernie Sanders', '0.5458'], ['None', '0.250...
# 184               1     [['Aaron Schock', '0.828'], ['None', '0.172']]
# 210               1  [['Katie Hill', '0.8039'], ['None', '0.1439'],...
#
#                                                   urls phase        state_x
# 56   ['http://sfgate.com/news/article/With-two-week...     E  Massachusetts
# 168  ['https://slate.com/news-and-politics/2020/01/...     E        Vermont
# 139  ['http://commondreams.org/news/2020/01/27/lead...     E        Vermont
# 184  ['https://www.peoriapublicradio.org/post/ex-re...     E       Illinois
# 210  ['https://twitchy.com/sarahd-313035/2020/02/21...     E     California

# %% [markdown]
# **Now, we want to see the distribution of hatecrime due to sexual orientation in each state.**

# %%
#Let's upload our data on hatecrime:
#We only keep data relevant for our subject, that is sexual orientation and gender identity
hc2015=pd.read_csv('data/hatecrime2015.csv')
hc2015.sort_index()
hc2015=hc2015.drop(columns=['Agency Type', 'Race/\nEthnicity/\nAncestry', 'Religion','Disability','Gender', '1st\nquarter'
                    , '2nd\nquarter','3rd\nquarter', '4th\nquarter', 'Agency name' ])

# %%
#remove unrelevant line spotted in the file
for i in range(hc2015.shape[0]):
    if (hc2015.State.loc[i]=='3 Includes one incident reported with more than one bias motivation.'):
        hc2015.State.loc[i]='NaN'
# Out:
# C:\Users\Pont Naomie\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
#The state value is filled once and then only NaN value for all the following rows until new state, therefore we fill in
# the NaN value with the relevant State 
hc=hc2015.fillna(method='ffill', axis=0)
hc=hc.rename(columns = {'Sexual\norientation': 'sexual_orientation', 'Gender\nIdentity': 'gender_identity'})

# %%
#last lines are non valid, therefore we drop them
hc=hc.drop(labels=[1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988], axis=0)

# %%
nb_hc=hc.groupby(['State']).sum()

# %%
#let's plot the distribution of sexual orientation related hate crime per state
plt.figure(figsize=(13,5))
plt.bar(nb_hc.index, nb_hc.sexual_orientation)
plt.xlabel('States')
plt.ylabel('Number of hate crimes')
plt.title('Distribution of sexual orientation related hate crime per state')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# We can see that California has the highest number of hate crime related to sexual orientation. It is interesting to point it out as we have seen in the previous plot that California has lots of speakers on the matter of gay rights.
#
# Indeed, after looking up on Internet, hate crimes with a sexual orientation bias are the second most common type of hate crime over 2006-2015 in California.

# %%
#same plot but for gender identity
plt.figure(figsize=(13,5))
plt.bar(nb_hc.index, nb_hc.gender_identity)
plt.xlabel('States')
plt.ylabel('Number of hate crimes')
plt.title('Distribution of gender identity related hate crime per state')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# We can see that gender identity related hate crime are not present in lots of state. It is probably because in 2015, we were less talking about gender identity than nowadays. Therefore, probably less people reported it as gender identity hate crime.
# Nevertheless, we can see that in Massachussetts and California, there have been important number of agressions. For Massachussetts, there are approximately same number of hate crime due to gender identity and sexual orientation, therfeore the whole lgbtqa+ community is very much targeted.

# %%
#get the number of occurences of all the quotations for a state
grouped_by_state = merged.groupby('state_x').agg({'numOccurrences' : sum})#sum()

#Add a column with the number of different quotations for a state
grouped_by_state['numQuotations']= merged.state_x.value_counts()
grouped_by_state.sort_values(by = 'numOccurrences', ascending=False)
grouped_by_state.head(5)
# Out:
#             numOccurrences  numQuotations
# state_x
# California              31             23
# Colorado                15             10
# Florida                 14              8
# Hawaii                   4              3
# Illinois                90             21

# %%
#visualization of the above table:
plt.figure(figsize=(10,5))
plt.bar(grouped_by_state.index, grouped_by_state.numQuotations, color='blue', label = "number of different quotations" )
plt.bar(grouped_by_state.index, grouped_by_state.numOccurrences, alpha=0.3, color='red', label="total number of occurences")
plt.legend(loc='best')
plt.xlabel('States')
plt.ylabel('Number of quotations')
plt.title('Difference between the number of different quotations and the total number of occurences per state')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This graph which represents differences between the number of different quotations and total number of occurences per state allows us to deduce if the topic of LGBT community is in the spotlights in specific states.
#
# Indeed, we can directly see in which sates there are a larger number of quotations and how many times they are quoted. For example, we can observe that in the state of vermont, the subject is widely spoken whereas in New Mexico there is only one quotation about the topic.

# %%
grouped_by_state['proportional_numQuotations'] = (grouped_by_state.numQuotations/grouped_by_state.numOccurrences)*100
plt.figure(figsize=(10,7))
plt.bar(grouped_by_state.index, 100-grouped_by_state.proportional_numQuotations, color='blue', alpha=0.6, label = "number of different quotations" )
plt.xlabel('States')
plt.ylabel('Proportion of viral quotations')
plt.xticks(rotation=90)
plt.title("Proportion of viral quotations in function of the states")
plt.show()

# %%
#file lgbt population:
lgbtpopulation=pd.read_csv("data/lgbtpopulation2021.csv")

#clean it:
lgbtpopulation=lgbtpopulation.dropna(how='any', axis=0)
lgbtpopulation.groupby("STATE").sum() #in case there are duplicates of states across rows
lgbtpopulation.sample(10)
# Out:
#              STATE TOTAL ADULT POPULATION LGBT ADULT POPULATION  \
# 19        KENTUCKY              4,468,402               144,000
# 16         INDIANA              6,691,878               272,000
# 41    PENNSYLVANIA             12,807,060               490,000
# 34        NEW YORK             19,542,209               913,000
# 35  NORTH CAROLINA             10,383,620               382,000
# 53   WEST VIRGINIA              1,805,832                68,000
# 15        ILLINOIS             12,741,080               506,000
# 28         MONTANA              1,062,305                30,000
# 55         WYOMING                577,737                18,000
# 18          KANSAS              2,911,505                92,000
#
#    LGBT POPULATION DENSITY % OF LGBTQ INDIVIDUALS RAISING CHILDREN  \
# 19                  3.400%                                  26.00%
# 16                  4.500%                                  34.00%
# 41                  4.100%                                  27.00%
# 34                  5.100%                                  22.00%
# 35                   4.00%                                  26.00%
# 53                   4.00%                                  31.00%
# 15                  4.300%                                  28.00%
# 28                  2.900%                                  19.00%
# 55                  3.300%                                  28.00%
# 18                  3.300%                                  33.00%
#
#    % OF SAME-SEX COUPLES RAISING CHILDREN
# 19                                18.500%
# 16                                18.900%
# 41                                15.900%
# 34                                16.400%
# 35                                18.500%
# 53                                17.800%
# 15                                16.600%
# 28                                 22.00%
# 55                                24.700%
# 18                                21.800%

# %%
lgbtpopulation=lgbtpopulation.sort_values(by=['LGBT POPULATION DENSITY'], axis=0)
plt.figure(figsize=(15,10))
plt.plot(lgbtpopulation['STATE'], lgbtpopulation['LGBT POPULATION DENSITY'])
plt.title("LGBT population density in function of the state")
plt.xticks(rotation=75)
plt.xlabel("State or territory")
plt.ylabel("Percentage of LGBT adult in 2015-2016")
plt.show()

# %% [markdown]
# We can see that North Dakota is the state with the smallest percentage of LGBT adults for the years 2015-2016, while in Oregon or in the District of Colombia the density is way higher. Note that these data are obtained from surveys (we guess) thus it doesn't correspond to the exact reality as some people may have not tell the truth or filled the form. Further studies will be interesting to see if these states are related to the ones where we have the more quotations, or how they are related to hate crimes for example.

# %%
#Correlation between LGBT population density and percentage of same-sex couples raising children
fig, ax = plt.subplots()
fig.set_size_inches(11.0, 8.0)
plt.xticks(rotation=75)
sns.scatterplot(data=lgbtpopulation, x='LGBT POPULATION DENSITY', y='% OF SAME-SEX COUPLES RAISING CHILDREN', ax=ax).set(title="Scatterplot of the % of same-sex couples raising children in function of LGBT population density per state") 
plt.show()

# %% [markdown]
# We will discuss it later, here we are just doing some pre-processing steps and visualizations but it seems that we have a negative correlation between these two categories.

# %%
#file lgbtsummary
lgbtsummary=pd.read_csv("data/lgbtsummary.csv")
lgbtsummary=lgbtsummary[:-1] #remove last row to sort by increasing population rank
lgbtsummary=lgbtsummary[['Pop.rank', 'State or territory', '2015–2016 LGBTadult percentageestimate[7]', 
                         '2016 transgender adult percentage estimate[2]']]
lgbtsummary=lgbtsummary.rename(columns={"2015–2016 LGBTadult percentageestimate[7]": 
                                        "Percentage of LGBT adult in 2015-2016", 
                                        "2016 transgender adult percentage estimate[2]": 
                                        "Percentage of transgender adult in 2016"})
lgbtsummary.head(lgbtsummary.shape[0]) #just to check that it is well ordered throughout the dataframe
# Out:
#    Pop.rank    State or territory Percentage of LGBT adult in 2015-2016  \
# 0         1            California                                  4.8%
# 1         2                 Texas                                  3.6%
# 2         3              New York                                  4.5%
# 3         4               Florida                                  4.2%
# 4         5              Illinois                                  3.7%
# 5         6                  Ohio                                  3.8%
# 6         7              Michigan                                  3.8%
# 7         8               Georgia                                  4.0%
# 8         9          Pennsylvania                                  3.6%
# 9        10            New Jersey                                  3.6%
# 10       11        North Carolina                                  3.5%
# 11       12         Massachusetts                                  4.9%
# 12       13            Washington                                  4.6%
# 13       14               Arizona                                  4.0%
# 14       15               Indiana                                  4.1%
# 15       16              Virginia                                  3.4%
# 16       17              Missouri                                  3.4%
# 17       18              Maryland                                  5.7%
# 18       19                Oregon                                  4.9%
# 19       20              Kentucky                                  3.3%
# 20       21             Tennessee                                  3.1%
# 21       22              Colorado                                  4.3%
# 22       23             Wisconsin                                  3.4%
# 23       24             Minnesota                                  4.0%
# 24       25             Louisiana                                  3.9%
# 25       26        South Carolina                                  3.5%
# 26       27               Alabama                                  3.0%
# 27       28              Oklahoma                                  3.5%
# 28       29                Nevada                                  4.8%
# 29       30                Kansas                                  3.1%
# 30       31              Arkansas                                  3.0%
# 31       32           Connecticut                                  3.5%
# 32       33                  Iowa                                  3.2%
# 33       34           Mississippi                                  3.2%
# 34       35                  Utah                                  3.3%
# 35       36                Hawaii                                  3.8%
# 36       37                 Maine                                  4.5%
# 37       38  District of Columbia                                  8.6%
# 38       39            New Mexico                                  4.2%
# 39       40         West Virginia                                  3.4%
# 40       41              Nebraska                                  3.6%
# 41       42         New Hampshire                                  4.6%
# 42       43          Rhode Island                                  4.0%
# 43       44                 Idaho                                  2.8%
# 44       45          South Dakota                                    2%
# 45       46              Delaware                                  4.7%
# 46       47               Vermont                                  5.3%
# 47       48               Montana                                  3.0%
# 48       49                Alaska                                  3.0%
# 49       50               Wyoming                                  3.5%
# 50       51          North Dakota                                  2.7%
#
#    Percentage of transgender adult in 2016
# 0                                    0.76%
# 1                                    0.66%
# 2                                    0.51%
# 3                                    0.66%
# 4                                    0.51%
# 5                                    0.45%
# 6                                    0.43%
# 7                                    0.75%
# 8                                    0.44%
# 9                                    0.44%
# 10                                   0.60%
# 11                                   0.57%
# 12                                   0.62%
# 13                                   0.62%
# 14                                   0.56%
# 15                                   0.55%
# 16                                   0.54%
# 17                                   0.49%
# 18                                   0.65%
# 19                                   0.53%
# 20                                   0.63%
# 21                                   0.53%
# 22                                   0.43%
# 23                                   0.59%
# 24                                   0.60%
# 25                                   0.58%
# 26                                   0.61%
# 27                                   0.64%
# 28                                   0.61%
# 29                                   0.43%
# 30                                   0.60%
# 31                                   0.44%
# 32                                   0.31%
# 33                                   0.61%
# 34                                   0.36%
# 35                                   0.78%
# 36                                   0.50%
# 37                                   2.77%
# 38                                   0.75%
# 39                                   0.42%
# 40                                   0.39%
# 41                                   0.43%
# 42                                   0.51%
# 43                                   0.41%
# 44                                   0.34%
# 45                                   0.64%
# 46                                   0.59%
# 47                                   0.34%
# 48                                   0.49%
# 49                                   0.32%
# 50                                   0.30%

# %%
lgbtsummary=lgbtsummary.sort_values(by='Percentage of LGBT adult in 2015-2016', axis=0)
plt.figure(figsize=(10,10))
#plt.bar(lgbtsummary['State or territory'],lgbtsummary['Percentage of LGBT adult in 2015-2016'])
plt.plot(lgbtsummary['State or territory'], lgbtsummary['Percentage of LGBT adult in 2015-2016'])
plt.xticks(rotation=90)
plt.xlabel("State or territory")
plt.ylabel("Percentage of LGBT adult in 2015-2016")
plt.title("LGBT population density in function of the state")
plt.show()

# %% [markdown]
# It shows similar results as in lgbtpopulation.

# %%
lgbtsummary=lgbtsummary.sort_values(by='Percentage of transgender adult in 2016', axis=0)
plt.figure(figsize=(10,10))
plt.plot(lgbtsummary['State or territory'], lgbtsummary['Percentage of transgender adult in 2016'])
plt.xticks(rotation=90)
plt.xlabel("State or territory")
plt.ylabel("Percentage of transgender adult in 2016")
plt.title("transgender population density in function of the state")
plt.show()

# %% [markdown]
# Same as for the lgbt population: the states with the highest and smallest density are respectively District of Columbia and North Dakota.
