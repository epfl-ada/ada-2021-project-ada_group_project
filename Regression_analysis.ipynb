# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
from statsmodels.stats import diagnostic
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
data_folder = './data/'
state_area=pd.read_csv(data_folder+"states_area.csv", sep=';')
population_size_state=pd.read_csv(data_folder+"population_size_state.csv", sep=';')
#population_size_region=pd.read_csv(data_folder+"population_size_region.csv", sep=';')
df_regression=pd.concat([population_size_state, state_area], axis=1)
df_regression.drop([df_regression.columns[0],'Rank'], axis=1, inplace=True)
df_regression
# Out:
#           2015        2016        2017        2018        2019        2020  \
# 0    4 854 803   4 866 824   4 877 989   4 891 628   4 907 965   4 921 532
# 1      738 430     742 575     740 983     736 624     733 603     731 158
# 2    6 832 810   6 944 767   7 048 088   7 164 228   7 291 843   7 421 401
# 3    2 979 732   2 991 815   3 003 855   3 012 161   3 020 985   3 030 522
# 4   38 904 296  39 149 186  39 337 785  39 437 463  39 437 610  39 368 078
# 5    5 454 328   5 543 844   5 617 421   5 697 155   5 758 486   5 807 719
# 6    3 588 561   3 579 830   3 575 324   3 574 561   3 566 022   3 557 006
# 7      942 065     949 989     957 942     966 985     976 668     986 809
# 8      677 014     687 576     697 079     704 147     708 253     712 816
# 9   20 219 111  20 627 237  20 977 089  21 254 926  21 492 056  21 733 312
# 10  10 183 353  10 308 442  10 417 031  10 519 389  10 628 020  10 710 017
# ...

# %% [markdown]
# The column labels **2015**, **2016**, ..., **2020** stand for the annual area of each USA state.
# Each of the columns (except State) of the dataframe df_regression will be used to run the regression.

# %%
#normalization:
#linear regression training:
